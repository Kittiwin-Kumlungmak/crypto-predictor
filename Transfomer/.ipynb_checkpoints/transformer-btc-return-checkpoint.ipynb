# %%
import pandas as pd
import numpy as np
import math
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
import torch
from DataLoader import Dataset
from Model import Transformer, AdamWarmup
from train import train
import torch.nn as nn
from joblib import load
from tools import *
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data/btc-usdt-1hr.csv').iloc[:,:6]
df['Open Time'] = pd.to_datetime(df['Open Time'], unit= 's')
df['Return'] = df['Close'].shift(1)/df['Close'] - 1
df = df[1:]
df
# Out:
#                Open Time      Open      High       Low     Close       Volume  \
# 1    2021-01-01 01:00:00  28995.13  29470.00  28960.35  29409.99  5403.068471
# 2    2021-01-01 02:00:00  29410.00  29465.26  29120.03  29194.65  2384.231560
# 3    2021-01-01 03:00:00  29195.25  29367.00  29150.02  29278.40  1461.345077
# 4    2021-01-01 04:00:00  29278.41  29395.00  29029.40  29220.31  2038.046803
# 5    2021-01-01 05:00:00  29220.31  29235.28  29084.11  29187.01  1469.956262
# ...                  ...       ...       ...       ...       ...          ...
# 5817 2021-08-31 20:00:00  47300.00  47322.71  46914.26  46992.60  1375.538340
# 5818 2021-08-31 21:00:00  46992.60  47200.00  46833.00  46911.50  1488.115700
# 5819 2021-08-31 22:00:00  46911.49  47104.96  46744.57  47088.84  1359.884290
# 5820 2021-08-31 23:00:00  47091.36  47345.00  46993.00  47100.89  1242.528870
# 5821 2021-09-01 00:00:00  47100.89  47321.42  46700.00  46754.74  2367.021480
#
#         Return
# 1    -0.014106
# 2     0.007376
# 3    -0.002860
# 4     0.001988
# 5     0.001141
# ...        ...
# 5817  0.006542
# 5818  0.001729
# 5819 -0.003766
# 5820 -0.000256
# 5821  0.007404
#
# [5821 rows x 7 columns]

# %%
plt.figure(figsize=(20,8))
plt.plot(df['Open Time'], df['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price (USDT)')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(20,8))
plt.plot(df['Open Time'], df['Return']*100)
plt.xlabel('Date')
plt.ylabel('% Return')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#Parameters
epochs = 100
d_model = 9
nhead = 9
num_encode_layer = 3
num_decode_layer = 0 #Only need the encoder
len_input = 48
dim_feedforward = 512
len_output = 1
warmup_steps = 200
dropout = 0.1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#Dataloader
train_dataset = Dataset('return-data/train-btc-dataset.csv', len_input)
train_loader = DataLoader(train_dataset, batch_size= 1)

val_dataset = Dataset('return-data/valid-btc-dataset.csv', len_input)
val_loader = DataLoader(train_dataset, batch_size= 1)

#Create model object
model = Transformer(d_model,
                    nhead = nhead,
                    num_encode_layer= num_encode_layer,
                    num_decode_layer= num_decode_layer,
                    dim_feedforward= dim_feedforward,
                    len_output = len_output,
                    dropout= dropout,
                    batch_first= True)

model.double().to(device)

#Create Adam optimizer with learning rate warmup
adam_optimizer = torch.optim.Adam(model.parameters(), lr = 0, betas=(0.9,0.98), eps = 1e-9)
adam_warmup= AdamWarmup(d_model, warmup_steps= warmup_steps, optimizer= adam_optimizer)

#Loss function
criterion = nn.MSELoss(reduction='none')

train_loss_hist = []
val_loss_hist = []
min_val_loss = float('inf')

#training loop
for epoch in range(epochs):
    train_loss, val_loss = train(train_loader= train_loader,
                                val_loader= val_loader,
                                len_input= len_input,
                                len_output= len_output,
                                model= model,
                                optim= adam_warmup,
                                criterion= criterion,
                                epoch= epoch,
                                device= device)
#     break
    if val_loss < min_val_loss:
        min_val_loss = val_loss
        best_state = {
            'epoch': epoch + 1,
            'model': model.state_dict(),
            'optimizer': adam_optimizer.state_dict(),
            'training loss': train_loss,
            'validation loss': val_loss
        }

    train_loss_hist.append(train_loss)
    val_loss_hist.append(val_loss)

    print('Epoch: [{}/{}] \t\t Trainig Loss: {:.3f}e-3 \t Validation Loss: {:.3f}e-3'.format(epoch+1, epochs, train_loss*1000, val_loss*1000))

    if early_stop(val_loss_hist, patience= 10, skip= 10):
        torch.save(best_state, f'checkpoints/{num_encode_layer}L-{len_input}HR-{dim_feedforward}FF-{warmup_steps}LRWU-Return.tar')
        break
# Out:
# Epoch: [1/100] 		 Trainig Loss: 22.648e-3 	 Validation Loss: 23.060e-3
# Epoch: [2/100] 		 Trainig Loss: 1.561e-3 	 Validation Loss: 32.332e-3
# Epoch: [3/100] 		 Trainig Loss: 1.170e-3 	 Validation Loss: 38.330e-3
# Epoch: [4/100] 		 Trainig Loss: 1.120e-3 	 Validation Loss: 38.646e-3
# Epoch: [5/100] 		 Trainig Loss: 1.117e-3 	 Validation Loss: 38.835e-3
# Epoch: [6/100] 		 Trainig Loss: 1.087e-3 	 Validation Loss: 36.661e-3
# Epoch: [7/100] 		 Trainig Loss: 1.084e-3 	 Validation Loss: 35.680e-3
# Epoch: [8/100] 		 Trainig Loss: 1.069e-3 	 Validation Loss: 35.629e-3
# Epoch: [9/100] 		 Trainig Loss: 1.069e-3 	 Validation Loss: 34.011e-3
# Epoch: [10/100] 		 Trainig Loss: 0.989e-3 	 Validation Loss: 35.720e-3
# Epoch: [11/100] 		 Trainig Loss: 1.047e-3 	 Validation Loss: 32.597e-3
# Epoch: [12/100] 		 Trainig Loss: 0.988e-3 	 Validation Loss: 32.234e-3
# Epoch: [13/100] 		 Trainig Loss: 1.023e-3 	 Validation Loss: 33.529e-3
# Epoch: [14/100] 		 Trainig Loss: 1.029e-3 	 Validation Loss: 30.951e-3
# Epoch: [15/100] 		 Trainig Loss: 1.024e-3 	 Validation Loss: 31.112e-3
# Epoch: [16/100] 		 Trainig Loss: 1.040e-3 	 Validation Loss: 31.051e-3
# Epoch: [17/100] 		 Trainig Loss: 1.042e-3 	 Validation Loss: 29.969e-3
# Epoch: [18/100] 		 Trainig Loss: 1.083e-3 	 Validation Loss: 28.145e-3
# Epoch: [19/100] 		 Trainig Loss: 1.072e-3 	 Validation Loss: 30.925e-3
# Epoch: [20/100] 		 Trainig Loss: 1.017e-3 	 Validation Loss: 31.113e-3
# Epoch: [53/100] 		 Trainig Loss: 1.101e-3 	 Validation Loss: 21.310e-3
# Epoch: [54/100] 		 Trainig Loss: 1.084e-3 	 Validation Loss: 20.512e-3
# Epoch: [55/100] 		 Trainig Loss: 1.070e-3 	 Validation Loss: 20.657e-3
# Epoch: [56/100] 		 Trainig Loss: 1.051e-3 	 Validation Loss: 20.972e-3
# Epoch: [57/100] 		 Trainig Loss: 1.051e-3 	 Validation Loss: 20.864e-3
# Epoch: [58/100] 		 Trainig Loss: 1.040e-3 	 Validation Loss: 21.507e-3
# Stop the training

# %%
plt.figure(figsize=(15,8))
plt.plot(np.array(train_loss_hist), label= 'Training Loss')
plt.plot(np.array(val_loss_hist), label= 'Validaion Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
epochs = 100
d_model = 9
nhead = 9
num_encode_layer = 3
num_decode_layer = 0 #Only need the encoder
len_input = 48
dim_feedforward = 512
len_output = 1
warmup_steps = 200
dropout = 0.1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


d_model = 9
nhead = 9
num_encode_layer = 3
num_decode_layer = 0 #Only need the encoder
len_input = 48
dim_feedforward = 512
len_output = 1
warmup_steps = 200
dropout = 0.1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
scaler = load('train-return-scaler.joblib')

model = Transformer(d_model,
                    nhead = nhead,
                    num_encode_layer= num_encode_layer,
                    num_decode_layer= num_decode_layer,
                    dim_feedforward= dim_feedforward,
                    len_output = len_output,
                    dropout= dropout,
                    batch_first= True)

best_state = torch.load('checkpoints/3L-48HR-512FF-200LRWU-Return.tar')
model.load_state_dict(best_state['model'])
model.double().to(device)

adam_optimizer = torch.optim.Adam(model.parameters(), lr = 0, betas=(0.9,0.98), eps = 1e-9)
adam_warmup= AdamWarmup(d_model, warmup_steps= warmup_steps, optimizer= adam_optimizer)
criterion = nn.MSELoss(reduction= 'none')

from validate import validate

val_dataset = Dataset('return-data/valid-btc-dataset.csv', len_input)
val_loader = DataLoader(val_dataset, batch_size= 1)

pred_hist, _ = validate(val_loader, len_input, len_output, model, scaler, criterion, device=device)


for i in range(len(pred_hist)):
    pred_hist[i] /= scaler.scale_[0]
    
val_df = pd.read_csv('return-data/valid-btc-raw.csv')
pred_close = {'Predicted Return' : pred_hist}
pred_df = pd.DataFrame(pred_close)
val_df['Predicted Return'] = pred_df.shift(len_input + len_output - 1)
val_df['Return'] = val_df['Close'].shift(1)/val_df['Close'] - 1

plt.figure(figsize=(30,12))
plt.xlabel('Hours')
plt.ylabel('Return')
plt.plot(val_df['Predicted Return'], label= 'Prediction')
plt.plot(val_df['Return'], label= 'Target')
plt.legend()
# Out:
# Prediction ended

# %%
val_df['Predicted Return'][48:]
# Out:
# 48      0.116532
# 49      0.115416
# 50      0.105127
# 51      0.105798
# 52      0.116290
#           ...
# 1159         NaN
# 1160         NaN
# 1161         NaN
# 1162         NaN
# 1163         NaN
# Name: Predicted Return, Length: 1116, dtype: float64

# %%
len(val_df['Return'])
# Out:
# 1163
